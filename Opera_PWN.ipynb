# %%
# !apt install wget -y
# !pip install webdriver_manager
# !pip install --upgrade webdriver_manager
# !wget -qO- https://deb.opera.com/archive.key | apt-key add -
# !add-apt-repository "deb [arch=i386,amd64] https://deb.opera.com/opera-stable/ stable non-free"
# !apt install -y opera-stable
# !pip install selenium==4.2.0
# !pip install faker
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# wget is already the newest version (1.20.3-1ubuntu2).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting webdriver_manager
#   Downloading webdriver_manager-3.8.6-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from webdriver_manager) (2.27.1)
# Collecting python-dotenv (from webdriver_manager)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from webdriver_manager) (4.65.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from webdriver_manager) (23.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->webdriver_manager) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->webdriver_manager) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->webdriver_manager) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->webdriver_manager) (3.4)
# Installing collected packages: python-dotenv, webdriver_manager
# Successfully installed python-dotenv-1.0.0 webdriver_manager-3.8.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: webdriver_manager in /usr/local/lib/python3.10/dist-packages (3.8.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from webdriver_manager) (2.27.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from webdriver_manager) (1.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from webdriver_manager) (4.65.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from webdriver_manager) (23.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->webdriver_manager) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->webdriver_manager) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->webdriver_manager) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->webdriver_manager) (3.4)
# OK
# Get:1 https://deb.opera.com/opera-stable stable InRelease [2,590 B]
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease [18.1 kB]
# Get:8 https://deb.opera.com/opera-stable stable/non-free amd64 Packages [1,182 B]
# Get:9 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:11 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1,051 kB]
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,346 kB]
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,202 kB]
# Hit:16 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:17 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main Sources [2,581 kB]
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main amd64 Packages [1,218 kB]
# Fetched 9,759 kB in 4s (2,564 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-codecs-ffmpeg-extra pepperflashplugin-nonfree
# The following NEW packages will be installed:
#   chromium-codecs-ffmpeg-extra opera-stable pepperflashplugin-nonfree
# 0 upgraded, 3 newly installed, 0 to remove and 34 not upgraded.
# Need to get 106 MB of archives.
# After this operation, 318 MB of additional disk space will be used.
# Get:1 https://deb.opera.com/opera-stable stable/non-free amd64 opera-stable amd64 99.0.4788.31 [106 MB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 1:85.0.4183.83-0ubuntu0.20.04.3 [3,040 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 pepperflashplugin-nonfree amd64 1.8.8~ubuntu20.04.1 [5,164 B]
# Fetched 106 MB in 1s (88.0 MB/s)
# Preconfiguring packages ...
# Selecting previously unselected package opera-stable.
# (Reading database ... 122545 files and directories currently installed.)
# Preparing to unpack .../opera-stable_99.0.4788.31_amd64.deb ...
# Unpacking opera-stable (99.0.4788.31) ...
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_1%3a85.0.4183.83-0ubuntu0.20.04.3_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (1:85.0.4183.83-0ubuntu0.20.04.3) ...
# Selecting previously unselected package pepperflashplugin-nonfree.
# Preparing to unpack .../pepperflashplugin-nonfree_1.8.8~ubuntu20.04.1_amd64.deb ...
# Unpacking pepperflashplugin-nonfree (1.8.8~ubuntu20.04.1) ...
# Setting up opera-stable (99.0.4788.31) ...
# update-alternatives: using /usr/bin/opera to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/x-www-browser.1.gz because associated file /usr/share/man/man1/opera.1.gz (of link group x-www-browser) doesn't exist
# update-alternatives: using /usr/bin/opera to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/gnome-www-browser.1.gz because associated file /usr/share/man/man1/opera.1.gz (of link group gnome-www-browser) doesn't exist
# Setting up chromium-codecs-ffmpeg-extra (1:85.0.4183.83-0ubuntu0.20.04.3) ...
# Setting up pepperflashplugin-nonfree (1.8.8~ubuntu20.04.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for shared-mime-info (1.15-1) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting selenium==4.2.0
#   Downloading selenium-4.2.0-py3-none-any.whl (983 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium==4.2.0) (1.26.15)
# Collecting trio~=0.17 (from selenium==4.2.0)
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 32.1 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium==4.2.0)
#   Downloading trio_websocket-0.10.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.2.0) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.2.0) (2.4.0)
# Collecting async-generator>=1.9 (from trio~=0.17->selenium==4.2.0)
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.2.0) (3.4)
# Collecting outcome (from trio~=0.17->selenium==4.2.0)
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.2.0) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.2.0) (1.1.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium==4.2.0)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[secure,socks]~=1.26->selenium==4.2.0) (1.7.1)
# Collecting pyOpenSSL>=0.14 (from urllib3[secure,socks]~=1.26->selenium==4.2.0)
#   Downloading pyOpenSSL-23.1.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=1.3.4 in /usr/local/lib/python3.10/dist-packages (from urllib3[secure,socks]~=1.26->selenium==4.2.0) (40.0.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from urllib3[secure,socks]~=1.26->selenium==4.2.0) (2022.12.7)
# Collecting urllib3-secure-extra (from urllib3[secure,socks]~=1.26->selenium==4.2.0)
#   Downloading urllib3_secure_extra-0.1.0-py2.py3-none-any.whl (1.4 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium==4.2.0) (1.15.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium==4.2.0)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium==4.2.0) (2.21)
# Installing collected packages: urllib3-secure-extra, outcome, h11, async-generator, wsproto, trio, trio-websocket, pyOpenSSL, selenium
# Successfully installed async-generator-1.10 h11-0.14.0 outcome-1.2.0 pyOpenSSL-23.1.1 selenium-4.2.0 trio-0.22.0 trio-websocket-0.10.2 urllib3-secure-extra-0.1.0 wsproto-1.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting faker
#   Downloading Faker-18.9.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Installing collected packages: faker
# Successfully installed faker-18.9.0

# %%
import time
import threading
import warnings

from faker import Faker
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as ec
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.opera.options import Options
from webdriver_manager.opera import OperaDriverManager

warnings.filterwarnings('ignore')
fake = Faker('en_IN')
MUTEX = threading.Lock()
executable_path = OperaDriverManager().install()
print(executable_path)


def sync_print(text):
    with MUTEX:
        print(text)


def getMIC(driver):
    print("Accessing Mic")
    pass


def get_driver():
    options = webdriver.ChromeOptions()
    options.headless = True
    # options.add_argument('allow-elevated-browser')
    options.add_experimental_option('w3c', True)
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    options.add_argument('--disable-gpu')
    options.add_argument('--disable-extensions')
    options.add_argument(f'--marionette-port=2828')  # Specify the port number here
    driver = webdriver.Opera(executable_path=executable_path, options=options)
    return driver


def driver_wait(driver, locator, by, secs=10, condition=ec.element_to_be_clickable):
    wait = WebDriverWait(driver=driver, timeout=secs)
    element = wait.until(condition((by, locator)))
    return element


def start(name, proxy, user, wait_time):
    sync_print(f"{name} started!")
    driver = get_driver() # Create a new driver instance for each thread
    driver.get(f'https://zoom.us/wc/join/{meetingcode}')
    time.sleep(10)
    inp = driver.find_element(By.XPATH, '//*[@id="inputname"]')
    time.sleep(1)
    inp.send_keys(f"{user}")
    time.sleep(5)

    inp2 = driver.find_element(By.ID, 'inputpasscode')
    time.sleep(2)
    inp2.send_keys(passcode)

    # Click the "Join" button using JavaScript
    join_button = driver.find_element(By.ID, 'joinBtn')
    driver.execute_script("arguments[0].click();", join_button)

    time.sleep(15)
    try:
        btn3 = driver.find_element(By.ID, 'preview-audio-control-button').click()
    except:
        pass
    
    try:
        WebDriverWait(driver, 20).until(ec.presence_of_element_located((By.XPATH,'//*[@id="root"]/div/div[1]/button')))
        driver.find_element(By.XPATH,'//*[@id="root"]/div/div[1]/button').click()
    except:
        pass
      
    try: 
        WebDriverWait(driver, 20).until(ec.presence_of_element_located((By.XPATH,'//*[@id="voip-tab"]/div/button')))
    except:
        pass
    sync_print(f"{name} sleep for {wait_time} seconds ...")
    time.sleep(wait_time)
    sync_print(f"{name} ended!")
    driver.quit() # Quit the driver after the thread has completed


def main():
    wait_time = sec * 60
    workers = []

    for i in range(number):
        try:
            proxy = proxylist[i]
        except Exception:
            proxy = None
        try:
            user = fake.name()
        except IndexError:
            break
        wk = threading.Thread(target=start, args=(
            f'[Thread{i}]', proxy, user, wait_time))
        workers.append(wk)
    for wk in workers:
        wk.start()
    for wk in workers:
        wk.join()


if __name__ == '__main__':
    number = int(input("Enter number of Users: "))
    meetingcode = input("Enter meeting code (No Space): ")
    passcode = input("Enter Password (No Space): ")
    sec = 60
    try:
        main()
    except:
        pass
# Out:
# [WDM] - Downloading: 7.27kB [00:00, 1.10MB/s]
# [WDM] - Downloading: 7.27kB [00:00, 1.62MB/s]
# [WDM] - Downloading: 100%|██████████| 6.83M/6.83M [00:00<00:00, 76.0MB/s]
# /root/.wdm/drivers/operadriver/linux64/v.112.0.5615.87/operadriver_linux64/operadriver
# Enter number of Users: 5
# Enter meeting code (No Space): 82770760919
# Enter Password (No Space): 468111
# [Thread0] started!
# [Thread1] started!
# [Thread2] started!
# [Thread3] started!
# [Thread4] started!
# [Thread1] sleep for 3600 seconds ...
# [Thread0] sleep for 3600 seconds ...
# [Thread4] sleep for 3600 seconds ...
# [Thread2] sleep for 3600 seconds ...
# [Thread3] sleep for 3600 seconds ...
